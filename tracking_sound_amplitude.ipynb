# %%
import IPython
from scipy.io import wavfile
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import librosa
import pandas as pd
ratex, datax = wavfile.read('audio1.wav')
rate, data = wavfile.read('test_noise.wav')
IPython.display.Audio(data=data, rate=rate)
print(max(data))

# %%
from scipy.fft import fft, fftfreq,rfft, rfftfreq,irfft

# %%
# Number of samples in normalized_tone
N = rate*4
print(rate)
N=int(N)
print(N)
# Out:
# 16000
# 64000

# %%
yf = rfft(data)
xf = rfftfreq(N, 1 / rate)
print(yf)
print(xf)
# Out:
# [ -473341.             +0.j            63811.46764674-125499.69738895j
#     97938.76221534 +87918.30070656j ...   232562.07151891-776150.50008233j
#  -1110136.08958654-469536.79286792j  1962061.             +0.j        ]
# [0.00000e+00 2.50000e-01 5.00000e-01 ... 7.99950e+03 7.99975e+03
#  8.00000e+03]

# %%
plt.plot(xf, list(np.abs(yf)))
plt.show()

# %%
yff = rfft(datax)
xff = rfftfreq(N, 1 / rate)
print(min(abs(yff)))
print(max(abs(yf)))
# Out:
# 101.82178362469809
# 12727871.268301506

# %%
plt.plot(xff, list(np.abs(yff)))
plt.show()

# %%
points_per_freq = len(xf) / (rate )
target_idx = int(points_per_freq * 5500)
for i in range(len(yf)):
    if xf[i]>2000:
        yf[i]=0
plt.plot(xf, np.abs(yf))
plt.show()

# %%
plt.plot(xf, (np.abs(yf)))
plt.show()

# %%
y = irfft(yf)

plt.plot(y)

# %%
IPython.display.Audio(data=y, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(y)
